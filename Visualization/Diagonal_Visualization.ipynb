# %% [markdown]
# **Environment Setup**

# %%
import numpy as np
from google.colab import drive
from matplotlib.lines import Line2D
from copy import deepcopy
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Necessary Parameter Setup**

# %%
max_warmup = 1000
warmup_window = 100

window_array = np.append(np.repeat(10, 10),
                      np.repeat(warmup_window, max_warmup // warmup_window - 1))

warmup_length = np.repeat(10, len(window_array))
for i in range(len(warmup_length) - 1):
    warmup_length[i + 1] = warmup_length[i] + window_array[i + 1]

# Transition kernel for short regime
repitition = 10
num_chains_short = 2048
num_super_chains = 16

# %%
# quantiles for chi squared with df = 1
chi_up = 3.841459 # 95th quantile for chi squared with df = 1
chi_lo = 0.00393214  # 05th quantile for chi squared with df = 1
tau = 1e-4
M = num_chains_short // num_super_chains
nRhat_lower = np.sqrt(1 + 1 / M + tau)
eps_lower = nRhat_lower - 1
bound = [chi_lo / num_chains_short, chi_up / num_chains_short]
threshold = eps_lower

# %%
utility_link = '/content/drive/MyDrive/JHU Stuff/Capstone/Utility_Functions/Plot_Utility.py'
with open(utility_link) as f: exec(f.read())

# %% [markdown]
# First Distribution with covariance matrix:
# $$
# \begin{bmatrix}
#   1 & 0 \\
#   0 & 1 \\
# \end{bmatrix}
# $$

# %%
# MSE vs Warmups:
MSE_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1_1_MSE_c.pkl"
MSE_c_df = pd.read_pickle(MSE_c_path)

MSE_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1_1_MSE_n.pkl"
MSE_n_df = pd.read_pickle(MSE_n_path)
# MSE vs nested Rhat:
R_hat_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1_1_Rhat_c.pkl"
R_Hat_c_df = pd.read_pickle(R_hat_c_path)

R_hat_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1_1_Rhat_n.pkl"
R_Hat_n_df = pd.read_pickle(R_hat_n_path)
print("Data Loaded!")
# Out:
# Data Loaded!

# %%
MSE_vs_Warmup(MSE_c_df, MSE_n_df, "Covariance 1-1")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 1-1 ",bound, threshold,
                  num_chains_short,"Warmup Length")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 1-1 ",bound, threshold,
                  num_chains_short,"Dimension")

# %% [markdown]
# Second Distribution with covariance matrix:
# $$
# \begin{bmatrix}
#   10 & 0 \\
#   0 & 1 \\
# \end{bmatrix}
# $$

# %%
# MSE vs Warmups:
MSE_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_10_1_MSE_c.pkl"
MSE_c_df = pd.read_pickle(MSE_c_path)

MSE_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_10_1_MSE_n.pkl"
MSE_n_df = pd.read_pickle(MSE_n_path)
# MSE vs nested Rhat:
R_hat_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_10_1_Rhat_c.pkl"
R_Hat_c_df = pd.read_pickle(R_hat_c_path)

R_hat_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_10_1_Rhat_n.pkl"
R_Hat_n_df = pd.read_pickle(R_hat_n_path)
print("Data Loaded!")
# Out:
# Data Loaded!

# %%
MSE_vs_Warmup(MSE_c_df, MSE_n_df, "Covariance 10-1")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 10-1 ",bound, threshold,
                  num_chains_short,"Warmup Length")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 10-1 ",bound, threshold,
                  num_chains_short,"Dimension")

# %% [markdown]
# Third Distribution with covariance matrix:
# $$
# \begin{bmatrix}
#   100 & 0 \\
#   0 & 1 \\
# \end{bmatrix}
# $$

# %%
# MSE vs Warmups:
MSE_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_100_1_MSE_c.pkl"
MSE_c_df = pd.read_pickle(MSE_c_path)

MSE_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_100_1_MSE_n.pkl"
MSE_n_df = pd.read_pickle(MSE_n_path)
# MSE vs nested Rhat:
R_hat_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_100_1_Rhat_c.pkl"
R_Hat_c_df = pd.read_pickle(R_hat_c_path)

R_hat_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_100_1_Rhat_n.pkl"
R_Hat_n_df = pd.read_pickle(R_hat_n_path)
print("Data Loaded!")
# Out:
# Data Loaded!

# %%
MSE_vs_Warmup(MSE_c_df, MSE_n_df, "Covariance 100-1")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 100-1 ",bound, threshold,
                  num_chains_short,"Warmup Length")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 100-1 ",bound, threshold,
                  num_chains_short,"Dimension")

# %% [markdown]
# 4-th Distribution with covariance matrix:
# $$
# \begin{bmatrix}
#   1000 & 0 \\
#   0 & 1 \\
# \end{bmatrix}
# $$

# %%
# MSE vs Warmups:
MSE_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1000_1_MSE_c.pkl"
MSE_c_df = pd.read_pickle(MSE_c_path)

MSE_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1000_1_MSE_n.pkl"
MSE_n_df = pd.read_pickle(MSE_n_path)
# MSE vs nested Rhat:
R_hat_c_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1000_1_Rhat_c.pkl"
R_Hat_c_df = pd.read_pickle(R_hat_c_path)

R_hat_n_path = "/content/drive/MyDrive/JHU Stuff/Capstone/pkl_Additional_Experiment/GeometryExperiment/Diag_1000_1_Rhat_n.pkl"
R_Hat_n_df = pd.read_pickle(R_hat_n_path)
print("Data Loaded!")
# Out:
# Data Loaded!

# %%
MSE_vs_Warmup(MSE_c_df, MSE_n_df, "Covariance 1000-1")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 1000-1 ",bound, threshold,
                  num_chains_short,"Warmup Length")

# %%
dfs = [R_Hat_c_df, R_Hat_n_df]
titles = ["Constrained", "Naive"]
MSE_vs_Rhat_color(dfs, titles,"Covariance 1000-1 ",bound, threshold,
                  num_chains_short,"Dimension")
